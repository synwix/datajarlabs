# %%
import pandas as pd
import numpy as np
import statistics
df = pd.DataFrame()
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df['Veri1'] = [28, 42, 27, 24, 35, 54, 35, 37]
df1['Veri2'] = [24, 51, 51, 34, 12, 42, 31, 21]
df2['Veri3'] = [98, 87, 78, 94, 71, 105, 110, 110]
#df
#veri2=np.append(np.random.normal(69, 8, 100), np.random.normal(64, 5, 100))
#veri3=np.append(np.random.normal(25, 8, 100), np.random.normal(25, 5, 100))
#print(rassal)
sum(df['Veri1']) / len(df['Veri1'])
#sum(df['a']) / len(df['a'])
#sum(df['b']) / len(df['b'])

print("Veri1 Ortalamasi")
print(np.mean(df['Veri1']))
                          
print()
print("Veri2 ortalamasi")
print(np.mean(df1['Veri2']))

print()
print("Veri3 ortalamasi")
print(np.mean(df2['Veri3']))

print()
print("Veri1 medyan")
print(np.median(df['Veri1']))
print()
print("Veri2 medyan")
print(np.median(df1['Veri2']))
print()
print("Veri3 medyan")
print(np.median(df2['Veri3']))


print()
print("Veri1 modu")
print(statistics.mode(df['Veri1']))

print()
print("Veri2 modu")
print(statistics.mode(df1['Veri2']))

print()
print("Veri3 modu")
print(statistics.mode(df2['Veri3']))

print()
print("Veri1 varyans")
print(np.var(df['Veri1'], ddof=1))

print()
print("Veri2 varyans")
print(np.var(df1['Veri2'], ddof=1))

print()
print("Veri3 varyans")
print(np.var(df2['Veri3'], ddof=1))

print()
print("Veri1 standart sapma")
print(np.std(df['Veri1'], ddof=1))

print()
print("Veri2 standart sapma")
print(np.std(df1['Veri2'], ddof=1))

print()
print("Veri3 standart sapma")
print(np.std(df2['Veri3'], ddof=1))

print()
print("1.Veri Standart Hata")
print(np.std(df['Veri1'] ,ddof=1) / np.sqrt(len(df['Veri1'])))
print()
print("2.Veri Standart Hata")
print(np.std(df1['Veri2'] ,ddof=1) / np.sqrt(len(df['Veri1'])))
print()
print("3.Veri Standart Hata")
print(np.std(df2['Veri3'] ,ddof=1) / np.sqrt(len(df['Veri1'])))
# Out:
# Veri1 Ortalamasi
# 35.25
#
# Veri2 ortalamasi
# 33.25
#
# Veri3 ortalamasi
# 94.125
#
# Veri1 medyan
# 35.0
#
# Veri2 medyan
# 32.5
#
# Veri3 medyan
# 96.0
#
# Veri1 modu
# 35
#
# Veri2 modu
# 51
#
# Veri3 modu
# 110
#
# Veri1 varyans
# 92.5
#
# Veri2 varyans
# 199.92857142857142
#
# Veri3 varyans
# 211.83928571428572
#
# Veri1 standart sapma
# 9.617692030835672
#
# Veri2 standart sapma
# 14.139610016848817
#
# Veri3 standart sapma
# 14.554699780974039
#
# 1.Veri Standart Hata
# 3.4003676271838605
#
# 2.Veri Standart Hata
# 4.999107063123516
#
# 3.Veri Standart Hata
# 5.14586345663055
