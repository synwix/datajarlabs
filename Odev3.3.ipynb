# %%
import matplotlib.pyplot as plt
import math
from scipy.stats import norm
import seaborn as sns
import pandas as pd
import numpy as np
#dağılım = np.random.dağılım_adı([],[])
dagilim =  np.random.normal(0.5, 0.1, 10000)
dagilim
plt.figure(figsize=(8,4), dpi = 100)
plt.hist(dagilim, bins = 50)
plt.show()

# %%
df = pd.DataFrame()
df = pd.read_csv("GOOG.csv")
df = df["Open"]
plt.figure()
plt.subplot(1,2,1)
plt.hist(df, bins = 50)
plt.subplot(1,2,2)
plt.hist(dagilim, bins = 50)
# Out:
# (array([  2.,   2.,   3.,   3.,   9.,   5.,  14.,  16.,  25.,  36.,  45.,
#          77., 108., 126., 174., 189., 269., 325., 374., 413., 466., 559.,
#         522., 533., 589., 601., 597., 553., 522., 457., 427., 422., 336.,
#         254., 219., 195., 162.,  97.,  85.,  60.,  33.,  22.,  28.,  16.,
#          11.,   8.,   7.,   1.,   1.,   2.]),
#  array([0.12199306, 0.13707135, 0.15214965, 0.16722794, 0.18230624,
#         0.19738453, 0.21246283, 0.22754112, 0.24261942, 0.25769771,
#         0.27277601, 0.2878543 , 0.3029326 , 0.31801089, 0.33308919,
#         0.34816748, 0.36324578, 0.37832407, 0.39340237, 0.40848066,
#         0.42355896, 0.43863725, 0.45371555, 0.46879384, 0.48387213,
#         0.49895043, 0.51402872, 0.52910702, 0.54418531, 0.55926361,
#         0.5743419 , 0.5894202 , 0.60449849, 0.61957679, 0.63465508,
#         0.64973338, 0.66481167, 0.67988997, 0.69496826, 0.71004656,
#         0.72512485, 0.74020315, 0.75528144, 0.77035974, 0.78543803,
#         0.80051633, 0.81559462, 0.83067292, 0.84575121, 0.86082951,
#         0.8759078 ]),
#  <a list of 50 Patch objects>)
